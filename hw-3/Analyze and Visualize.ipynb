# %% [markdown]
# # I. Numpy

# %% [markdown]
# ### Импортируйте NumPy

# %%
import numpy as np

# %% [markdown]
# ### Создайте одномерный массив размера 10, заполненный нулями и пятым элемент равным 1. Трансформируйте в двумерный массив.

# %%
# Создаем одномерный массив размера 10, заполненный нулями.
array = np.zeros(10)

# Устанавливаем пятый элемент равным 1.
array[4] = 1

# Трансформируем одномерный массив в двумерный массив (reshape)
array_2d = array.reshape(2, 5)

# %% [markdown]
# ### Создайте одномерный массив со значениями от 10 до 49 и разверните его (первый элемент становится последним). Найдите в нем все четные элементы.

# %%
# Создаем одномерный массив со значениями от 10 до 49.
array = np.arange(10, 50)

# Разворачиваем массив.
reversed_array = array[::-1]

# Находим все четные элементы.
even_elements = reversed_array[reversed_array % 2 == 0]

# %% [markdown]
# ### Создайте двумерный массив 3x3 со значениями от 0 до 8

# %%
# Создаем одномерный массив со значениями от 0 до 8.
array = np.arange(9)

# Преобразуем одномерный массив в двумерный массив 3x3.
array_2d = array.reshape(3, 3)

# %% [markdown]
# ### Создайте массив 4x3x2 со случайными значениями. Найти его минимум и максимум.

# %%
# Создаем массив размером 4x3x2 со случайными значениями.
array = np.random.random((4, 3, 2))

# Находим минимум и максимум.
min_value = array.min()
max_value = array.max()

# %% [markdown]
# ### Создайте два двумерных массива размерами 6x4 и 4x3 и произведите их матричное умножение.

# %%
# Создаем два двумерных массива размерами 6x4 и 4x3 с рандомными значениями от 1 до 9.
a = np.random.randint(1, 10, size=(6, 4))
b = np.random.randint(1, 10, size=(4, 3))

# Производим умножение матриц.
c = np.dot(a, b)

# %% [markdown]
# ### Создайте случайный двумерный массив 7x7, найти у него среднее и стандартное оклонение. Нормализуйте этот массив.

# %%
# Создание случайного двумерного массива размером 7x7.
array = np.random.random((7, 7))

# Нахождение среднего и стандартного отклонения.
mean = np.mean(array)
std_dev = np.std(array)

# Нормализация массива (приведение к стандартному нормальному распределению).
normalized_array = (array - mean) / std_dev

# %% [markdown]
# # II. Pandas

# %% [markdown]
# ### Импортируйте: pandas, matplotlib, seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Загрузите датасет Tips из набора датасетов seaborn

# %%
# Загрузка датасета Tips из seaborn.
tips = sns.load_dataset('tips')

# %% [markdown]
# ### Посмотрите на первые 5 строчек

# %%
# Печать первых 5 строк датасета.
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Узнайте сколько всего строчек и колонок в данных

# %%
# Получаем количество строк и количество колонок.
num_rows, num_columns = tips.shape

# %% [markdown]
# ### Проверьте есть ли пропуски в данных

# %%
# Проверяем на наличие пропусков в данных.
missing_values = tips.isnull().sum()

# %% [markdown]
# ### Посмотрите на распределение числовых признаков

# %%
# Определение числовых признаков.
numeric_features = tips.select_dtypes(include=['float64', 'int64'])

# Построение распределения числовых признаков.
plt.figure(figsize=(12, 8))

for i, column in enumerate(numeric_features.columns, 1):
    plt.subplot(2, 3, i)  # 2x3 сетка для подграфиков.
    sns.histplot(tips[column], kde=True)
    plt.title(f'Распределение {column}')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Найдите максимальное значение 'total_bill'

# %%
# Максимальне значение в столбце 'total_bill'.
max_total_bill = tips['total_bill'].max()

# %% [markdown]
# ### Найдите количество курящих людей

# %%
# Подсчет количества курящих людей.
num_smokers = tips['smoker'].value_counts().get('Yes', 0)

# %% [markdown]
# ### Узнайте какой средний 'total_bill' в зависимости от 'day'

# %%
# Группировка данных по 'day' и вычисление среднего значения 'total_bill'.
average_total_bill_by_day = tips.groupby('day', observed=True)['total_bill'].mean()

# %% [markdown]
# ### Отберите строчки с 'total_bill' больше медианы и узнайте какой средний 'tip' в зависимости от 'sex'

# %%
# Вычисление медианы столбца 'total_bill'.
median_total_bill = tips['total_bill'].median()

# Отбор строк с 'total_bill' больше медианы.
filtered_tips = tips[tips['total_bill'] > median_total_bill]

# Группировка отфильтрованных данных по 'sex' и вычисление среднего значения 'tip'.
average_tip_by_sex = filtered_tips.groupby('sex', observed=True)['tip'].mean()

# %% [markdown]
# ### Преобразуйте признак 'smoker' в бинарный (0-No, 1-Yes)

# %%
# Преобразование признака 'smoker' в бинарный формат.
tips['smoker_binary'] = tips['smoker'].map({'No': 0, 'Yes': 1})

# %% [markdown]
# # III. Visualization

# %% [markdown]
# ### Постройте гистограмму распределения признака 'total_bill'

# %%
# Построение гистограммы распределения признака 'total_bill'
plt.figure(figsize=(10, 6))
sns.histplot(tips['total_bill'], bins=30, kde=True)
plt.title('Распределение total_bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Постройте scatterplot, представляющий взаимосвязь между признаками 'total_bill' и 'tip'

# %%
# Построение scatterplot для 'total_bill' и 'tip'.
plt.figure(figsize=(10, 6))
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title('Взаимосвязь между total_bill и tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# ### Постройте pairplot

# %%
# Построение pairplot для всех числовых признаков.
sns.pairplot(tips)
plt.suptitle('Pairplot всех числовых признаков', y=1.02)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Постройте график взаимосвязи между признаками 'total_bill' и 'day'

# %%
# Построение boxplot для 'total_bill' и 'day'.
plt.figure(figsize=(10, 6))
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title('Взаимосвязь между total_bill и day')
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ### Постройте две гистограммы распределения признака 'tip' в зависимости от категорий 'time'

# %%
# Установка размера графика.
plt.figure(figsize=(14, 6))

# Построение гистограммы для обеда (Lunch).
plt.subplot(1, 2, 1)
sns.histplot(tips[tips['time'] == 'Lunch']['tip'], bins=15, kde=True)
plt.title('Распределение чаевых (tip) во время обеда')
plt.xlabel('Tip')
plt.ylabel('Frequency')

# Построение гистограммы для ужина (Dinner).
plt.subplot(1, 2, 2)
sns.histplot(tips[tips['time'] == 'Dinner']['tip'], bins=15, kde=True)
plt.title('Распределение чаевых (tip) во время ужина')
plt.xlabel('Tip')
plt.ylabel('Frequency')

# Отображение графиков.
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Постройте два графика scatterplot, представляющих взаимосвязь между признаками 'total_bill' и 'tip' один для Male, другой для Female и раскрасьте точки в зависимоти от признака 'smoker'

# %%
# Установка размера графика.
plt.figure(figsize=(14, 6))

# Построение scatterplot для мужчин (Male).
plt.subplot(1, 2, 1)
sns.scatterplot(x='total_bill', y='tip', hue='smoker', data=tips[tips['sex'] == 'Male'], palette={'Yes': 'red', 'No': 'blue'})
plt.title('Взаимосвязь между total_bill и tip для мужчин')
plt.xlabel('Total Bill')
plt.ylabel('Tip')

# Построение scatterplot для женщин (Female).
plt.subplot(1, 2, 2)
sns.scatterplot(x='total_bill', y='tip', hue='smoker', data=tips[tips['sex'] == 'Female'], palette={'Yes': 'red', 'No': 'blue'})
plt.title('Взаимосвязь между total_bill и tip для женщин')
plt.xlabel('Total Bill')
plt.ylabel('Tip')

# Отображение графиков
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Сделайте выводы по анализу датасета и построенным графикам. По желанию можете продолжить анализ данных и также отразить это в выводах.

# %%
# Датасет Tips содержит информацию о счетах и чаевых в ресторане, а также дополнительные сведения о клиенте, такие как пол (sex), время посещения (time), день недели (day) и информация о курении (smoker).
# Датасет позволяет анализировать взаимосвязи между этими признаками.
